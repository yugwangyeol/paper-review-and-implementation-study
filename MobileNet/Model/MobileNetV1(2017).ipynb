# %%
from google.colab import drive
drive.mount('mobilenet')
# Out:
# Mounted at mobilenet

# %%
# import package

# model
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary
from torch import optim

# dataset and transformation
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import os

# display images
from torchvision import utils
import matplotlib.pyplot as plt
# %matplotlib inline

# utils
import numpy as np
from torchsummary import summary
import time
import copy

# %% [markdown]
# # 1. 데이터셋 불러오기
#  데이터셋은 torchvision 패키지에서 제공하는 STL10 dataset을 이용하겠습니다. STL10 dataset은 10개의 label을 갖으며 train dataset 5000개, test dataset 8000개로 구성됩니다.

# %%
# specify path to data
path2data = '/content/mobilenet/MyDrive/data'

# if not exists the path, make the directory
if not os.path.exists(path2data):
    os.mkdir(path2data)

# load dataset
train_ds = datasets.STL10(path2data, split='train', download=True, transform=transforms.ToTensor())
val_ds = datasets.STL10(path2data, split='test', download=True, transform=transforms.ToTensor())

print(len(train_ds))
print(len(val_ds))
# Out:
# Downloading http://ai.stanford.edu/~acoates/stl10/stl10_binary.tar.gz to /content/mobilenet/MyDrive/data/stl10_binary.tar.gz
#   0%|          | 0/2640397119 [00:00<?, ?it/s]
# Extracting /content/mobilenet/MyDrive/data/stl10_binary.tar.gz to /content/mobilenet/MyDrive/data
# Files already downloaded and verified
# 5000
# 8000

# %%
# define transformation
transformation = transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Resize(224)
])

# apply transformation to dataset
train_ds.transform = transformation
val_ds.transform = transformation

# make dataloade
train_dl = DataLoader(train_ds, batch_size=32, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=32, shuffle=True)

# %%
# check sample images
def show(img, y=None):
    npimg = img.numpy()
    npimg_tr = np.transpose(npimg, (1, 2, 0))
    plt.imshow(npimg_tr)

    if y is not None:
        plt.title('labels:' + str(y))

np.random.seed(10)
torch.manual_seed(0)

grid_size=4
rnd_ind = np.random.randint(0, len(train_ds), grid_size)

x_grid = [train_ds[i][0] for i in rnd_ind]
y_grid = [val_ds[i][1] for i in rnd_ind]

x_grid = utils.make_grid(x_grid, nrow=grid_size, padding=2)
plt.figure(figsize=(10,10))
show(x_grid, y_grid)

# %% [markdown]
# # 2. 모델 구축하기
#  코드는 https://github.com/weiaicunzai/pytorch-cifar100/blob/master/models/mobilenet.py 를 참고했습니다.

# %%
# Depthwise Separable Convolution
class Depthwise(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()

        self.depthwise = nn.Sequential(
            nn.Conv2d(in_channels, in_channels, 3, stride=stride, padding=1, groups=in_channels, bias=False),
            nn.BatchNorm2d(in_channels),
            nn.ReLU6(),
        )

        self.pointwise = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, 1, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU6()
        )
    
    def forward(self, x):
        x = self.depthwise(x)
        x = self.pointwise(x)
        return x


# Basic Conv2d
class BasicConv2d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, **kwargs):
        super().__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, **kwargs),
            nn.BatchNorm2d(out_channels),
            nn.ReLU()
        )

    def forward(self, x):
        x = self.conv(x)
        return x


# MobileNetV1
class MobileNet(nn.Module):
    def __init__(self, width_multiplier, num_classes=10, init_weights=True):
        super().__init__()
        self.init_weights=init_weights
        alpha = width_multiplier

        self.conv1 = BasicConv2d(3, int(32*alpha), 3, stride=2, padding=1)
        self.conv2 = Depthwise(int(32*alpha), int(64*alpha), stride=1)
        # down sample
        self.conv3 = nn.Sequential(
            Depthwise(int(64*alpha), int(128*alpha), stride=2),
            Depthwise(int(128*alpha), int(128*alpha), stride=1)
        )
        # down sample
        self.conv4 = nn.Sequential(
            Depthwise(int(128*alpha), int(256*alpha), stride=2),
            Depthwise(int(256*alpha), int(256*alpha), stride=1)
        )
        # down sample
        self.conv5 = nn.Sequential(
            Depthwise(int(256*alpha), int(512*alpha), stride=2),
            Depthwise(int(512*alpha), int(512*alpha), stride=1),
            Depthwise(int(512*alpha), int(512*alpha), stride=1),
            Depthwise(int(512*alpha), int(512*alpha), stride=1),
            Depthwise(int(512*alpha), int(512*alpha), stride=1),
            Depthwise(int(512*alpha), int(512*alpha), stride=1),
        )
        # down sample
        self.conv6 = nn.Sequential(
            Depthwise(int(512*alpha), int(1024*alpha), stride=2)
        )
        # down sample
        self.conv7 = nn.Sequential(
            Depthwise(int(1024*alpha), int(1024*alpha), stride=2)
        )

        self.avg_pool = nn.AdaptiveAvgPool2d((1,1))
        self.linear = nn.Linear(int(1024*alpha), num_classes)

        # weights initialization
        if self.init_weights:
            self._initialize_weights()

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        x = self.conv6(x)
        x = self.conv7(x)
        x = self.avg_pool(x)
        x = x.view(x.size(0), -1)
        x = self.linear(x)
        return x

    # weights initialization function
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

def mobilenet(alpha=1, num_classes=10):
    return MobileNet(alpha, num_classes)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
x = torch.randn((3, 3, 224, 224)).to(device)
model = mobilenet(alpha=1).to(device)
output = model(x)
print('output size:', output.size())
# Out:
# output size: torch.Size([3, 10])

# %%
summary(model, (3, 224, 224), device=device.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 32, 112, 112]             896
#        BatchNorm2d-2         [-1, 32, 112, 112]              64
#               ReLU-3         [-1, 32, 112, 112]               0
#        BasicConv2d-4         [-1, 32, 112, 112]               0
#             Conv2d-5         [-1, 32, 112, 112]             288
#        BatchNorm2d-6         [-1, 32, 112, 112]              64
#              ReLU6-7         [-1, 32, 112, 112]               0
#             Conv2d-8         [-1, 64, 112, 112]           2,048
#        BatchNorm2d-9         [-1, 64, 112, 112]             128
#             ReLU6-10         [-1, 64, 112, 112]               0
#         Depthwise-11         [-1, 64, 112, 112]               0
#            Conv2d-12           [-1, 64, 56, 56]             576
#       BatchNorm2d-13           [-1, 64, 56, 56]             128
#             ReLU6-14           [-1, 64, 56, 56]               0
#            Conv2d-15          [-1, 128, 56, 56]           8,192
#       BatchNorm2d-16          [-1, 128, 56, 56]             256
#             ReLU6-17          [-1, 128, 56, 56]               0
#         Depthwise-18          [-1, 128, 56, 56]               0
#            Conv2d-19          [-1, 128, 56, 56]           1,152
#       BatchNorm2d-20          [-1, 128, 56, 56]             256
#             ReLU6-21          [-1, 128, 56, 56]               0
#            Conv2d-22          [-1, 128, 56, 56]          16,384
#       BatchNorm2d-23          [-1, 128, 56, 56]             256
#             ReLU6-24          [-1, 128, 56, 56]               0
#         Depthwise-25          [-1, 128, 56, 56]               0
#            Conv2d-26          [-1, 128, 28, 28]           1,152
#       BatchNorm2d-27          [-1, 128, 28, 28]             256
#             ReLU6-28          [-1, 128, 28, 28]               0
#            Conv2d-29          [-1, 256, 28, 28]          32,768
#       BatchNorm2d-30          [-1, 256, 28, 28]             512
#             ReLU6-31          [-1, 256, 28, 28]               0
#         Depthwise-32          [-1, 256, 28, 28]               0
#            Conv2d-33          [-1, 256, 28, 28]           2,304
#       BatchNorm2d-34          [-1, 256, 28, 28]             512
#             ReLU6-35          [-1, 256, 28, 28]               0
#            Conv2d-36          [-1, 256, 28, 28]          65,536
#       BatchNorm2d-37          [-1, 256, 28, 28]             512
#             ReLU6-38          [-1, 256, 28, 28]               0
#         Depthwise-39          [-1, 256, 28, 28]               0
#            Conv2d-40          [-1, 256, 14, 14]           2,304
#       BatchNorm2d-41          [-1, 256, 14, 14]             512
#             ReLU6-42          [-1, 256, 14, 14]               0
#            Conv2d-43          [-1, 512, 14, 14]         131,072
#       BatchNorm2d-44          [-1, 512, 14, 14]           1,024
#             ReLU6-45          [-1, 512, 14, 14]               0
#         Depthwise-46          [-1, 512, 14, 14]               0
#            Conv2d-47          [-1, 512, 14, 14]           4,608
#       BatchNorm2d-48          [-1, 512, 14, 14]           1,024
#             ReLU6-49          [-1, 512, 14, 14]               0
#            Conv2d-50          [-1, 512, 14, 14]         262,144
#       BatchNorm2d-51          [-1, 512, 14, 14]           1,024
#             ReLU6-52          [-1, 512, 14, 14]               0
#         Depthwise-53          [-1, 512, 14, 14]               0
#            Conv2d-54          [-1, 512, 14, 14]           4,608
#       BatchNorm2d-55          [-1, 512, 14, 14]           1,024
#             ReLU6-56          [-1, 512, 14, 14]               0
#            Conv2d-57          [-1, 512, 14, 14]         262,144
#       BatchNorm2d-58          [-1, 512, 14, 14]           1,024
#             ReLU6-59          [-1, 512, 14, 14]               0
#         Depthwise-60          [-1, 512, 14, 14]               0
#            Conv2d-61          [-1, 512, 14, 14]           4,608
#       BatchNorm2d-62          [-1, 512, 14, 14]           1,024
#             ReLU6-63          [-1, 512, 14, 14]               0
#            Conv2d-64          [-1, 512, 14, 14]         262,144
#       BatchNorm2d-65          [-1, 512, 14, 14]           1,024
#             ReLU6-66          [-1, 512, 14, 14]               0
#         Depthwise-67          [-1, 512, 14, 14]               0
#            Conv2d-68          [-1, 512, 14, 14]           4,608
#       BatchNorm2d-69          [-1, 512, 14, 14]           1,024
#             ReLU6-70          [-1, 512, 14, 14]               0
#            Conv2d-71          [-1, 512, 14, 14]         262,144
#       BatchNorm2d-72          [-1, 512, 14, 14]           1,024
#             ReLU6-73          [-1, 512, 14, 14]               0
#         Depthwise-74          [-1, 512, 14, 14]               0
#            Conv2d-75          [-1, 512, 14, 14]           4,608
#       BatchNorm2d-76          [-1, 512, 14, 14]           1,024
#             ReLU6-77          [-1, 512, 14, 14]               0
#            Conv2d-78          [-1, 512, 14, 14]         262,144
#       BatchNorm2d-79          [-1, 512, 14, 14]           1,024
#             ReLU6-80          [-1, 512, 14, 14]               0
#         Depthwise-81          [-1, 512, 14, 14]               0
#            Conv2d-82            [-1, 512, 7, 7]           4,608
#       BatchNorm2d-83            [-1, 512, 7, 7]           1,024
#             ReLU6-84            [-1, 512, 7, 7]               0
#            Conv2d-85           [-1, 1024, 7, 7]         524,288
#       BatchNorm2d-86           [-1, 1024, 7, 7]           2,048
#             ReLU6-87           [-1, 1024, 7, 7]               0
#         Depthwise-88           [-1, 1024, 7, 7]               0
#            Conv2d-89           [-1, 1024, 4, 4]           9,216
#       BatchNorm2d-90           [-1, 1024, 4, 4]           2,048
#             ReLU6-91           [-1, 1024, 4, 4]               0
#            Conv2d-92           [-1, 1024, 4, 4]       1,048,576
#       BatchNorm2d-93           [-1, 1024, 4, 4]           2,048
#             ReLU6-94           [-1, 1024, 4, 4]               0
#         Depthwise-95           [-1, 1024, 4, 4]               0
# AdaptiveAvgPool2d-96           [-1, 1024, 1, 1]               0
#            Linear-97                   [-1, 10]          10,250
# ================================================================
# Total params: 3,217,258
# Trainable params: 3,217,258
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 137.36
# Params size (MB): 12.27
# Estimated Total Size (MB): 150.20
# ----------------------------------------------------------------

# %% [markdown]
# # 3. 학습하기

# %%
# define loss function, optimizer, lr_scheduler
loss_func = nn.CrossEntropyLoss(reduction='sum')
opt = optim.Adam(model.parameters(), lr=0.01)

from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min', factor=0.1, patience=10)


# get current lr
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']


# calculate the metric per mini-batch
def metric_batch(output, target):
    pred = output.argmax(1, keepdim=True)
    corrects = pred.eq(target.view_as(pred)).sum().item()
    return corrects


# calculate the loss per mini-batch
def loss_batch(loss_func, output, target, opt=None):
    loss_b = loss_func(output, target)
    metric_b = metric_batch(output, target)

    if opt is not None:
        opt.zero_grad()
        loss_b.backward()
        opt.step()
    
    return loss_b.item(), metric_b


# calculate the loss per epochs
def loss_epoch(model, loss_func, dataset_dl, sanity_check=False, opt=None):
    running_loss = 0.0
    running_metric = 0.0
    len_data = len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb = xb.to(device)
        yb = yb.to(device)
        output = model(xb)

        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)

        running_loss += loss_b
        
        if metric_b is not None:
            running_metric += metric_b

        if sanity_check is True:
            break

    loss = running_loss / len_data
    metric = running_metric / len_data
    return loss, metric


# function to start training
def train_val(model, params):
    num_epochs=params['num_epochs']
    loss_func=params['loss_func']
    opt=params['optimizer']
    train_dl=params['train_dl']
    val_dl=params['val_dl']
    sanity_check=params['sanity_check']
    lr_scheduler=params['lr_scheduler']
    path2weights=params['path2weights']

    loss_history = {'train': [], 'val': []}
    metric_history = {'train': [], 'val': []}

    best_loss = float('inf')
    best_model_wts = copy.deepcopy(model.state_dict())
    start_time = time.time()

    for epoch in range(num_epochs):
        current_lr = get_lr(opt)
        print('Epoch {}/{}, current lr= {}'.format(epoch, num_epochs-1, current_lr))

        model.train()
        train_loss, train_metric = loss_epoch(model, loss_func, train_dl, sanity_check, opt)
        loss_history['train'].append(train_loss)
        metric_history['train'].append(train_metric)

        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl, sanity_check)
        loss_history['val'].append(val_loss)
        metric_history['val'].append(val_metric)

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), path2weights)
            print('Copied best model weights!')

        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print('Loading best model weights!')
            model.load_state_dict(best_model_wts)

        print('train loss: %.6f, val loss: %.6f, accuracy: %.2f, time: %.4f min' %(train_loss, val_loss, 100*val_metric, (time.time()-start_time)/60))
        print('-'*10)

    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %%
# define the training parameters
params_train = {
    'num_epochs':100,
    'optimizer':opt,
    'loss_func':loss_func,
    'train_dl':train_dl,
    'val_dl':val_dl,
    'sanity_check':False,
    'lr_scheduler':lr_scheduler,
    'path2weights':'./models/weights.pt',
}

# check the directory to save weights.pt
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSerror:
        print('Error')
createFolder('./models')

# %%
model, loss_hist, metric_hist = train_val(model, params_train)
# Out:
# Epoch 0/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.926429, val loss: 2.129567, accuracy: 23.12, time: 1.2739 min
# ----------
# Epoch 1/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.681883, val loss: 1.667031, accuracy: 32.00, time: 2.5262 min
# ----------
# Epoch 2/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.608973, val loss: 1.651783, accuracy: 35.55, time: 3.7803 min
# ----------
# Epoch 3/99, current lr= 0.01
# train loss: 1.552596, val loss: 1.677809, accuracy: 39.20, time: 5.0274 min
# ----------
# Epoch 4/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.491273, val loss: 1.503163, accuracy: 41.62, time: 6.2824 min
# ----------
# Epoch 5/99, current lr= 0.01
# train loss: 1.391841, val loss: 1.552298, accuracy: 41.40, time: 7.5344 min
# ----------
# Epoch 6/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.336118, val loss: 1.304819, accuracy: 50.50, time: 8.7913 min
# ----------
# Epoch 7/99, current lr= 0.01
# train loss: 1.255496, val loss: 1.783994, accuracy: 38.82, time: 10.0615 min
# ----------
# Epoch 8/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.162323, val loss: 1.185689, accuracy: 56.74, time: 11.3269 min
# ----------
# Epoch 9/99, current lr= 0.01
# train loss: 1.075556, val loss: 1.380811, accuracy: 52.30, time: 12.5818 min
# ----------
# Epoch 10/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.006785, val loss: 1.160911, accuracy: 58.16, time: 13.8335 min
# ----------
# Epoch 11/99, current lr= 0.01
# Copied best model weights!
# train loss: 0.918865, val loss: 1.139334, accuracy: 58.86, time: 15.0932 min
# ----------
# Epoch 12/99, current lr= 0.01
# Copied best model weights!
# train loss: 0.867852, val loss: 1.124095, accuracy: 60.90, time: 16.3564 min
# ----------
# Epoch 13/99, current lr= 0.01
# Copied best model weights!
# train loss: 0.795137, val loss: 1.096293, accuracy: 62.16, time: 17.6186 min
# ----------
# Epoch 14/99, current lr= 0.01
# train loss: 0.759948, val loss: 1.117004, accuracy: 60.60, time: 18.8756 min
# ----------
# Epoch 15/99, current lr= 0.01
# train loss: 0.673761, val loss: 1.105880, accuracy: 62.49, time: 20.1308 min
# ----------
# Epoch 16/99, current lr= 0.01
# train loss: 0.612852, val loss: 1.258135, accuracy: 59.36, time: 21.3842 min
# ----------
# Epoch 17/99, current lr= 0.01
# train loss: 0.546534, val loss: 1.226196, accuracy: 62.62, time: 22.6368 min
# ----------
# Epoch 18/99, current lr= 0.01
# train loss: 0.511280, val loss: 1.244427, accuracy: 63.50, time: 23.8946 min
# ----------
# Epoch 19/99, current lr= 0.01
# train loss: 0.435724, val loss: 1.367357, accuracy: 62.94, time: 25.1464 min
# ----------
# Epoch 20/99, current lr= 0.01
# train loss: 0.432929, val loss: 1.283199, accuracy: 62.09, time: 26.4062 min
# ----------
# Epoch 21/99, current lr= 0.01
# train loss: 0.346950, val loss: 1.389735, accuracy: 62.02, time: 27.6542 min
# ----------
# Epoch 22/99, current lr= 0.01
# train loss: 0.348257, val loss: 1.457928, accuracy: 61.69, time: 28.8939 min
# ----------
# Epoch 23/99, current lr= 0.01
# train loss: 0.338935, val loss: 1.341114, accuracy: 64.09, time: 30.1367 min
# ----------
# Epoch 24/99, current lr= 0.01
# Loading best model weights!
# train loss: 0.284276, val loss: 1.338686, accuracy: 65.03, time: 31.3894 min
# ----------
# Epoch 25/99, current lr= 0.001
# Copied best model weights!
# train loss: 0.512976, val loss: 0.968977, accuracy: 67.60, time: 32.6351 min
# ----------
# Epoch 26/99, current lr= 0.001
# train loss: 0.389216, val loss: 1.017927, accuracy: 68.21, time: 33.8728 min
# ----------
# Epoch 27/99, current lr= 0.001
# train loss: 0.306555, val loss: 1.084260, accuracy: 68.08, time: 35.1057 min
# ----------
# Epoch 28/99, current lr= 0.001
# train loss: 0.226960, val loss: 1.159712, accuracy: 67.50, time: 36.3439 min
# ----------
# Epoch 29/99, current lr= 0.001
# train loss: 0.174027, val loss: 1.223453, accuracy: 67.81, time: 37.5811 min
# ----------
# Epoch 30/99, current lr= 0.001
# train loss: 0.123056, val loss: 1.378696, accuracy: 67.07, time: 38.8324 min
# ----------
# Epoch 31/99, current lr= 0.001
# train loss: 0.090381, val loss: 1.461694, accuracy: 67.25, time: 40.0900 min
# ----------
# Epoch 32/99, current lr= 0.001
# train loss: 0.068352, val loss: 1.575428, accuracy: 66.45, time: 41.3435 min
# ----------
# Epoch 33/99, current lr= 0.001
# train loss: 0.054814, val loss: 1.581467, accuracy: 66.86, time: 42.5976 min
# ----------
# Epoch 34/99, current lr= 0.001
# train loss: 0.044433, val loss: 1.626363, accuracy: 66.59, time: 43.8520 min
# ----------
# Epoch 35/99, current lr= 0.001
# train loss: 0.033270, val loss: 1.734508, accuracy: 65.86, time: 45.1047 min
# ----------
# Epoch 36/99, current lr= 0.001
# Loading best model weights!
# train loss: 0.037469, val loss: 1.755401, accuracy: 65.83, time: 46.3565 min
# ----------
# Epoch 37/99, current lr= 0.0001
# train loss: 0.381881, val loss: 0.982009, accuracy: 67.42, time: 47.6055 min
# ----------
# Epoch 38/99, current lr= 0.0001
# train loss: 0.368075, val loss: 0.980814, accuracy: 67.95, time: 48.8477 min
# ----------
# Epoch 39/99, current lr= 0.0001
# train loss: 0.354866, val loss: 1.001797, accuracy: 68.16, time: 50.0937 min
# ----------
# Epoch 40/99, current lr= 0.0001
# train loss: 0.350690, val loss: 1.011540, accuracy: 67.89, time: 51.3331 min
# ----------
# Epoch 41/99, current lr= 0.0001
# train loss: 0.328473, val loss: 1.013609, accuracy: 68.42, time: 52.5779 min
# ----------
# Epoch 42/99, current lr= 0.0001
# train loss: 0.322774, val loss: 1.029280, accuracy: 68.03, time: 53.8210 min
# ----------
# Epoch 43/99, current lr= 0.0001
# train loss: 0.311168, val loss: 1.047188, accuracy: 68.04, time: 55.0664 min
# ----------
# Epoch 44/99, current lr= 0.0001
# train loss: 0.293332, val loss: 1.040477, accuracy: 68.04, time: 56.3154 min
# ----------
# Epoch 45/99, current lr= 0.0001
# train loss: 0.289090, val loss: 1.057696, accuracy: 68.09, time: 57.5664 min
# ----------
# Epoch 46/99, current lr= 0.0001
# train loss: 0.271650, val loss: 1.054991, accuracy: 68.35, time: 58.8144 min
# ----------
# Epoch 47/99, current lr= 0.0001
# Loading best model weights!
# train loss: 0.267980, val loss: 1.071483, accuracy: 68.17, time: 60.0570 min
# ----------
# Epoch 48/99, current lr= 1e-05
# Copied best model weights!
# train loss: 0.378602, val loss: 0.968687, accuracy: 67.66, time: 61.2998 min
# ----------
# Epoch 49/99, current lr= 1e-05
# Copied best model weights!
# train loss: 0.386561, val loss: 0.957252, accuracy: 68.12, time: 62.5400 min
# ----------
# Epoch 50/99, current lr= 1e-05
# train loss: 0.389880, val loss: 0.968505, accuracy: 67.26, time: 63.7842 min
# ----------
# Epoch 51/99, current lr= 1e-05
# train loss: 0.387716, val loss: 0.980330, accuracy: 67.73, time: 65.0215 min
# ----------
# Epoch 52/99, current lr= 1e-05
# train loss: 0.376705, val loss: 0.971552, accuracy: 67.21, time: 66.2611 min
# ----------
# Epoch 53/99, current lr= 1e-05
# train loss: 0.391610, val loss: 0.980357, accuracy: 67.40, time: 67.5009 min
# ----------
# Epoch 54/99, current lr= 1e-05
# train loss: 0.382166, val loss: 0.975469, accuracy: 68.04, time: 68.7408 min
# ----------
# Epoch 55/99, current lr= 1e-05
# train loss: 0.375033, val loss: 0.978972, accuracy: 67.85, time: 69.9835 min
# ----------
# Epoch 56/99, current lr= 1e-05
# train loss: 0.376715, val loss: 0.966806, accuracy: 68.09, time: 71.2257 min
# ----------
# Epoch 57/99, current lr= 1e-05
# train loss: 0.372144, val loss: 0.974637, accuracy: 68.33, time: 72.4711 min
# ----------
# Epoch 58/99, current lr= 1e-05
# train loss: 0.371711, val loss: 0.978554, accuracy: 68.16, time: 73.7105 min
# ----------
# Epoch 59/99, current lr= 1e-05
# train loss: 0.368245, val loss: 0.972321, accuracy: 68.16, time: 74.9391 min
# ----------
# Epoch 60/99, current lr= 1e-05
# Loading best model weights!
# train loss: 0.376763, val loss: 0.978918, accuracy: 67.66, time: 76.1716 min
# ----------
# Epoch 61/99, current lr= 1.0000000000000002e-06
# train loss: 0.387987, val loss: 0.972073, accuracy: 67.67, time: 77.3992 min
# ----------
# Epoch 62/99, current lr= 1.0000000000000002e-06
# train loss: 0.386178, val loss: 0.968987, accuracy: 67.70, time: 78.6364 min
# ----------
# Epoch 63/99, current lr= 1.0000000000000002e-06
# train loss: 0.393572, val loss: 0.973405, accuracy: 67.46, time: 79.8798 min
# ----------
# Epoch 64/99, current lr= 1.0000000000000002e-06
# train loss: 0.381002, val loss: 0.964822, accuracy: 67.76, time: 81.1158 min
# ----------
# Epoch 65/99, current lr= 1.0000000000000002e-06
# train loss: 0.394719, val loss: 0.970878, accuracy: 67.80, time: 82.3492 min
# ----------
# Epoch 66/99, current lr= 1.0000000000000002e-06
# train loss: 0.374127, val loss: 0.976030, accuracy: 67.90, time: 83.5785 min
# ----------
# Epoch 67/99, current lr= 1.0000000000000002e-06
# train loss: 0.384355, val loss: 0.987563, accuracy: 66.99, time: 84.7985 min
# ----------
# Epoch 68/99, current lr= 1.0000000000000002e-06
# train loss: 0.378431, val loss: 0.967390, accuracy: 67.55, time: 86.0154 min
# ----------
# Epoch 69/99, current lr= 1.0000000000000002e-06
# train loss: 0.384290, val loss: 0.960336, accuracy: 67.83, time: 87.2314 min
# ----------
# Epoch 70/99, current lr= 1.0000000000000002e-06
# train loss: 0.382297, val loss: 0.961750, accuracy: 67.65, time: 88.4734 min
# ----------
# Epoch 71/99, current lr= 1.0000000000000002e-06
# Loading best model weights!
# train loss: 0.384372, val loss: 0.969023, accuracy: 68.06, time: 89.7044 min
# ----------
# Epoch 72/99, current lr= 1.0000000000000002e-07
# train loss: 0.387619, val loss: 0.977679, accuracy: 67.80, time: 90.9505 min
# ----------
# Epoch 73/99, current lr= 1.0000000000000002e-07
# train loss: 0.382715, val loss: 0.991824, accuracy: 66.88, time: 92.1872 min
# ----------
# Epoch 74/99, current lr= 1.0000000000000002e-07
# train loss: 0.382935, val loss: 0.970585, accuracy: 68.12, time: 93.4191 min
# ----------
# Epoch 75/99, current lr= 1.0000000000000002e-07
# train loss: 0.380629, val loss: 0.970941, accuracy: 67.64, time: 94.6488 min
# ----------
# Epoch 76/99, current lr= 1.0000000000000002e-07
# train loss: 0.387598, val loss: 0.969432, accuracy: 67.64, time: 95.8852 min
# ----------
# Epoch 77/99, current lr= 1.0000000000000002e-07
# train loss: 0.391484, val loss: 0.978025, accuracy: 67.77, time: 97.1379 min
# ----------
# Epoch 78/99, current lr= 1.0000000000000002e-07
# train loss: 0.392879, val loss: 0.981593, accuracy: 67.20, time: 98.3834 min
# ----------
# Epoch 79/99, current lr= 1.0000000000000002e-07
# train loss: 0.387421, val loss: 0.987999, accuracy: 67.58, time: 99.6364 min
# ----------
# Epoch 80/99, current lr= 1.0000000000000002e-07
# train loss: 0.386489, val loss: 0.980006, accuracy: 67.20, time: 100.8772 min
# ----------
# Epoch 81/99, current lr= 1.0000000000000002e-07
# train loss: 0.393814, val loss: 0.966773, accuracy: 67.73, time: 102.1188 min
# ----------
# Epoch 82/99, current lr= 1.0000000000000002e-07
# Loading best model weights!
# train loss: 0.389218, val loss: 0.977261, accuracy: 67.51, time: 103.3614 min
# ----------
# Epoch 83/99, current lr= 1.0000000000000004e-08
# train loss: 0.387312, val loss: 0.973437, accuracy: 67.64, time: 104.5984 min
# ----------
# Epoch 84/99, current lr= 1.0000000000000004e-08
# train loss: 0.390689, val loss: 0.963935, accuracy: 67.62, time: 105.8352 min
# ----------
# Epoch 85/99, current lr= 1.0000000000000004e-08
# train loss: 0.387252, val loss: 0.969005, accuracy: 67.99, time: 107.0709 min
# ----------
# Epoch 86/99, current lr= 1.0000000000000004e-08
# train loss: 0.389574, val loss: 0.977104, accuracy: 67.55, time: 108.3059 min
# ----------
# Epoch 87/99, current lr= 1.0000000000000004e-08
# train loss: 0.379552, val loss: 0.964128, accuracy: 67.84, time: 109.5431 min
# ----------
# Epoch 88/99, current lr= 1.0000000000000004e-08
# train loss: 0.388588, val loss: 0.981767, accuracy: 67.38, time: 110.7830 min
# ----------
# Epoch 89/99, current lr= 1.0000000000000004e-08
# train loss: 0.384540, val loss: 0.964410, accuracy: 67.64, time: 112.0230 min
# ----------
# Epoch 90/99, current lr= 1.0000000000000004e-08
# train loss: 0.389435, val loss: 0.970250, accuracy: 67.53, time: 113.2689 min
# ----------
# Epoch 91/99, current lr= 1.0000000000000004e-08
# train loss: 0.386024, val loss: 0.979760, accuracy: 67.05, time: 114.5100 min
# ----------
# Epoch 92/99, current lr= 1.0000000000000004e-08
# train loss: 0.378054, val loss: 0.982660, accuracy: 67.06, time: 115.7475 min
# ----------
# Epoch 93/99, current lr= 1.0000000000000004e-08
# train loss: 0.381681, val loss: 0.970217, accuracy: 67.84, time: 116.9874 min
# ----------
# Epoch 94/99, current lr= 1.0000000000000004e-08
# train loss: 0.386962, val loss: 0.967342, accuracy: 67.75, time: 118.2272 min
# ----------
# Epoch 95/99, current lr= 1.0000000000000004e-08
# train loss: 0.392744, val loss: 0.970044, accuracy: 67.29, time: 119.4681 min
# ----------
# Epoch 96/99, current lr= 1.0000000000000004e-08
# train loss: 0.391723, val loss: 0.968546, accuracy: 67.62, time: 120.7070 min
# ----------
# Epoch 97/99, current lr= 1.0000000000000004e-08
# train loss: 0.388492, val loss: 0.987202, accuracy: 67.40, time: 121.9501 min
# ----------
# Epoch 98/99, current lr= 1.0000000000000004e-08
# train loss: 0.383224, val loss: 0.981694, accuracy: 67.31, time: 123.1913 min
# ----------
# Epoch 99/99, current lr= 1.0000000000000004e-08
# train loss: 0.382646, val loss: 0.969199, accuracy: 67.84, time: 124.4304 min
# ----------

# %%
# train-val progress
num_epochs = params_train['num_epochs']

# plot loss progress
plt.title('Train-Val Loss')
plt.plot(range(1, num_epochs+1), loss_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), loss_hist['val'], label='val')
plt.ylabel('Loss')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()

# plot accuracy progress
plt.title('Train-Val Accuracy')
plt.plot(range(1, num_epochs+1), metric_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), metric_hist['val'], label='val')
plt.ylabel('Accuracy')
plt.xlabel('Training Epochs')
plt.legend()
plt.show()
